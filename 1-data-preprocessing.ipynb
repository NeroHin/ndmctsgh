# %% [markdown]
# ```
# action：
# 1. 合併資料到每一個病人的資料中
# 2. 檢查資料的完整性
# 3. 將資料轉換為可以被機器學習的資料
# 4. 進行訓練和測試
#
# ```

# %%
import pandas as pd
import os, glob, sys

train_data_path = 'train.csv'
ecg_data_folder = 'ecg/'

# read ecg folder files
ecg_file_path = []


def load_data(filename):
    df = pd.read_csv(filename)
    return df
  
def add_uid_col_in_data(df, filename: str):
    df['UID'] = filename.split('.')[0]
    return df


for root, dirs, files in os.walk(ecg_data_folder):
  for file in files:
    fullpath = os.path.join(root, file)
    ecg_file_path.append(fullpath)

# %%
train_df = load_data(train_data_path)

ecg_test_df= ['ecg/U00001.csv','ecg/U00002.csv']

# 可以先 add uid col 然後再 append 一個完整的 ecg 、再來 merge 到 train_df

for ecg in ecg_test_df:
    print(ecg)
    ecg_df = load_data(ecg)
    ecg_df['UID'] = ecg.split('/')[1].split('.')[0]
    print(ecg_df.head())
    # append ecg_df with all ecg_df
    ecg_df.append(ecg_df, ignore_index=True)
    # merge_df = pd.merge(train_df, ecg_df, on='UID')
    # final_df = pd.DataFrame(merge_df)
    # final_df = final_df.append(merge_df)
ecg_df
# Out:
# ecg/U00001.csv
#    leadI  leadII  leadIII  leadaVR  leadaVL  leadaVF  leadV1  leadV2  leadV3  \
# 0      4       7        3       -6        0        5      -4      -4      -5
# 1     30      56       23      -43        2       40     -43     -66     -57
# 2    -10      -9       -1        9       -5       -4     -31     -62     -73
# 3    -23     -37      -14       29       -6      -25       5     -11     -49
# 4    -20     -36      -17       28       -2      -26      19      19     -28
#
#    leadV4  leadV5  leadV6     UID
# 0      -3       7       8  U00001
# 1     -26      31      54  U00001
# 2     -60     -34     -14  U00001
# 3     -65     -67     -70  U00001
# 4     -50     -55     -67  U00001
# ecg/U00002.csv
#    leadI  leadII  leadIII  leadaVR  leadaVL  leadaVF  leadV1  leadV2  leadV3  \
# 0     -2      -2        0        2        0       -1       0       0       0
# 1     -1      -6       -5        4        1       -6      -1      -1      -1
# 2     -1     -10       -9        5        3       -9       0       0       0
# 3      2      -8      -11        3        5      -10      -1       0       0
# 4     -3      -8       -5        5        0       -7       1       1       2
#
#    leadV4  leadV5  leadV6     UID
# 0       1       1     -48  U00002
# 1       6       5    -225  U00002
# 2       6       5    -241  U00002
# 3       5       3    -247  U00002
# 4       7       5    -246  U00002
#      leadI  leadII  leadIII  leadaVR  leadaVL  leadaVF  leadV1  leadV2  \
# 0       -2      -2        0        2        0       -1       0       0
# 1       -1      -6       -5        4        1       -6      -1      -1
# 2       -1     -10       -9        5        3       -9       0       0
# 3        2      -8      -11        3        5      -10      -1       0
# 4       -3      -8       -5        5        0       -7       1       1
# ..     ...     ...      ...      ...      ...      ...     ...     ...
# 995    -13     -15      -10       -4       -9      -12      -6      -7
# 996    -12     -14      -11       -4       -9      -12      -5      -6
# 997     -9     -16      -16       -5       -6      -16      -6      -8
# 998    -15     -16      -10       -2      -11      -14      -5      -5
# 999    -16     -17       -9       -2      -12      -13      -4      -5
#
#      leadV3  leadV4  leadV5  leadV6     UID
# 0         0       1       1     -48  U00002
# 1        -1       6       5    -225  U00002
# 2         0       6       5    -241  U00002
# 3         0       5       3    -247  U00002
# 4         2       7       5    -246  U00002
# ..      ...     ...     ...     ...     ...
# 995      -5      -4      -3     -19  U00002
# 996      -4      -4      -3     -20  U00002
# 997      -5      -6      -4     -17  U00002
# 998      -3      -4      -3      -5  U00002
# 999      -2      -4      -3      -1  U00002
#
# [1000 rows x 13 columns]
